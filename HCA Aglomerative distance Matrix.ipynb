# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
import pandas as pd
data= [[0,9,3,6,11],[9,0,7,5,10],[3,7,0,9,2],[6,5,9,0,8],[11,10,2,8,0]]
points = ["a","b","c","d","e"]

df1 = pd.DataFrame(data,columns=["a","b","c","d","e"], index=points)
#df1 = pd.DataFrame(data,index=points)
df1
# Out:
#     a   b  c  d   e
# a   0   9  3  6  11
# b   9   0  7  5  10
# c   3   7  0  9   2
# d   6   5  9  0   8
# e  11  10  2  8   0

# %%
a:0,b:1,c:2,d:3,e:4

# %%
linkage_data = linkage(df1, method='ward', metric='euclidean')
dendrogram(linkage_data)

plt.show()
# Out:
# /var/folders/2b/7j09kw1d0k9bgb6mny3b09h80000gp/T/ipykernel_55447/3993542929.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_data = linkage(df1, method='ward', metric='euclidean')

# %%
linkage_data = linkage(df1, method='complete', metric='euclidean')
dendrogram(linkage_data)

plt.show()
# Out:
# /var/folders/2b/7j09kw1d0k9bgb6mny3b09h80000gp/T/ipykernel_55447/4090968773.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_data = linkage(df1, method='complete', metric='euclidean')

# %%
linkage_data = linkage(df1, method='single', metric='euclidean')
dendrogram(linkage_data)

plt.show()
# Out:
# /var/folders/2b/7j09kw1d0k9bgb6mny3b09h80000gp/T/ipykernel_55447/979888506.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_data = linkage(df1, method='single', metric='euclidean')

# %%
linkage_data = linkage(df1, method='average', metric='euclidean')
dendrogram(linkage_data)

plt.show()
# Out:
# /var/folders/2b/7j09kw1d0k9bgb6mny3b09h80000gp/T/ipykernel_55447/759041246.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_data = linkage(df1, method='average', metric='euclidean')
